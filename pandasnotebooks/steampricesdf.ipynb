# %%
from sqlalchemy import create_engine
import pandas as pd

import pymysql
pymysql.install_as_MySQLdb()
import json

# %%
games_df = pd.read_csv("games-features.csv")

# %%
#short_list = games_df.head(1).to_json()
#parsed = (json.loads(short_list))
#print(json.dumps(parsed, indent = 4, sort_keys=True))

# %%
rename_games = games_df[['ResponseName','IsFree','Metacritic','PCMinReqsText','PriceFinal','ReleaseDate','DLCCount']]
rename_games.head()
# Out:
#                 ResponseName  IsFree  Metacritic  \
# 0             Counter-Strike   False          88
# 1      Team Fortress Classic   False           0
# 2              Day of Defeat   False          79
# 3         Deathmatch Classic   False           0
# 4  Half-Life: Opposing Force   False           0
#
#                                        PCMinReqsText  PriceFinal ReleaseDate  \
# 0  Minimum: 500 mhz processor 96mb ram 16mb video...        9.99  Nov 1 2000
# 1  Minimum: 500 mhz processor 96mb ram 16mb video...        4.99  Apr 1 1999
# 2  Minimum: 500 mhz processor 96mb ram 16mb video...        4.99  May 1 2003
# 3  Minimum: 500 mhz processor 96mb ram 16mb video...        4.99  Jun 1 2001
# 4  Minimum: 500 mhz processor 96mb ram 16mb video...        4.99  Nov 1 1999
#
#    DLCCount
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
rename_games.loc[rename_games['ResponseName'] == 'Fallout 4']
# Out:
#      ResponseName  IsFree  Metacritic  \
# 6747    Fallout 4   False          84
#
#                                           PCMinReqsText  PriceFinal  \
# 6747  Minimum:OS: Windows 7/8/10 (64-bit OS required...       59.99
#
#      ReleaseDate  DLCCount
# 6747  Nov 9 2015         7

# %%
pricedf = rename_games.sort_values('PriceFinal', ascending=False).rename(columns={"ResponseName":"Name"})

# %%
#pricedf.rename(columns={"ResponseName":"Name"})
pricedf
# Out:
#                                                     Name  IsFree  Metacritic  \
# 4030              SolidFace Parametric CAD Modeler 2D/3D   False           0
# 3222                   VEGAS Pro 13 Edit - Steam Powered   False           0
# 5017                                 Atavism MMO Creator   False           0
# 12271                    VEGAS Pro 14 Edit Steam Edition   False           0
# 12838                     Marvelous Designer 6 For Steam   False           0
# 6757                                    ChessBase 13 Pro   False           0
# 9940           CyberLink PowerDirector 14 Ultimate Suite   False           0
# 5711                                         Rapture Pro   False           0
# 8884                     3DF Zephyr Lite 2 Steam Edition   False           0
# 13043                                 Marmoset Toolbag 3   False           0
# 9419                                 Substance Painter 2   False           0
# ...

# %%
#pricedf = pricedf.reset_index()
#pricedf.columns[0] = 'keyid'
#pricedf['keyid'] = pricedf.index + 42000

# %%
steam_df = pd.read_csv("steam_200k.csv")

# %%
steamdf2 = steam_df.rename(columns={'Name of the steam game':'Name'})
pricedf.head()
# Out:
#                                          Name  IsFree  Metacritic  \
# 4030   SolidFace Parametric CAD Modeler 2D/3D   False           0
# 3222        VEGAS Pro 13 Edit - Steam Powered   False           0
# 5017                      Atavism MMO Creator   False           0
# 12271         VEGAS Pro 14 Edit Steam Edition   False           0
# 12838          Marvelous Designer 6 For Steam   False           0
#
#                                            PCMinReqsText  PriceFinal  \
# 4030   Minimum:OS: Support Windows (r) XP/Vista/7/8Pr...      449.99
# 3222   Minimum:OS: 64-bit Microsoft(r) Windows 7 Wind...      399.99
# 5017   Minimum:OS: Windows XP SP2+Memory: 2 GB RAMDir...      399.00
# 12271  Minimum:OS: Windows 7 | 8 | 8.1 | 10 (64-bit)P...      399.00
# 12838  Minimum:OS: Microsoft Windows Vista (64bit)Pro...      320.00
#
#        ReleaseDate  DLCCount
# 4030   Dec 22 2014         0
# 3222    Nov 2 2015         0
# 5017   Jan 20 2015         0
# 12271  Sep 30 2016         0
# ...

# %%
df_new = pd.merge(steamdf2, pricedf, on = 'Name')

# %%
df_new.head()
# Out:
#    Unnamed: 0    User ID       Name  behavior  \
# 0           1  151603712  Fallout 4  purchase
# 1           2  151603712  Fallout 4      play
# 2        3186   87445402  Fallout 4  purchase
# 3        3187   87445402  Fallout 4      play
# 4        5682   25096601  Fallout 4  purchase
#
#    hours (1 if play, otherwise purchase)  IsFree  Metacritic  \
# 0                                    1.0   False          84
# 1                                   87.0   False          84
# 2                                    1.0   False          84
# 3                                   83.0   False          84
# 4                                    1.0   False          84
#
#                                        PCMinReqsText  PriceFinal ReleaseDate  \
# 0  Minimum:OS: Windows 7/8/10 (64-bit OS required...       59.99  Nov 9 2015
# 1  Minimum:OS: Windows 7/8/10 (64-bit OS required...       59.99  Nov 9 2015
# 2  Minimum:OS: Windows 7/8/10 (64-bit OS required...       59.99  Nov 9 2015
# ...

# %%
#pricedf.to_csv('VGPrices.csv')

# %%
steamdpricedf = df_new[['Name','User ID', 'PriceFinal', 'DLCCount', 'behavior', 'hours (1 if play, otherwise purchase)', 'IsFree', 'Metacritic',]]

# %%
steamplayprice = steamdpricedf[steamdpricedf['behavior'] != 'purchase']

# %%
steamplayprice2 = steamplayprice2.rename(columns = {'hours (1 if play, otherwise purchase)':'hours'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4cb610dac6e9> in <module>()
# ----> 1 steamplayprice2 = steamplayprice2.rename(columns = {'hours (1 if play, otherwise purchase)':'hours'})
#
# NameError: name 'steamplayprice2' is not defined

# %%
steamplayprice2.to_csv('VGPrices2.csv')

# %%
engine = create_engine("mysql://root:Honda2013!@localhost/steamprices")

# %%
steamplayprice2.to_sql(name='steamprices',con=engine, if_exists = 'append', index=False)

# %%
steamplayprice2 = steamplayprice.sort_values('PriceFinal', ascending=False)

# %%
steamplayprice2

# %%
engine = create_engine("mysql://root:Honda2013!@localhost/steamprices")
pricedf.to_sql(name='steamprices',con=engine, if_exists = 'append', index=False)

# %%
#import pymongo
#conn = 'mongodb://localhost:27017'

# %%
#data = pricedf.to_dict(orient='records')

# %%
#client = pymongo.MongoClient(conn)

# %%
#db = client.vgprices

# %%
#db.vgprices.insert_many(data)

# %%
#list(db.vgprices.find())
